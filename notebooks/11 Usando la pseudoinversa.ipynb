# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-5, 5, 1000)

y_1 = -4*x + 3
y_2 = 2*x + 5
y_3 = -3*x + 1 

plt.plot(x, y_1)
plt.plot(x, y_2)
plt.plot(x, y_3)

plt.xlim(-2, 2.5)
plt.ylim(-6, 6)

plt.show()

# %%
matriz = np.array([[4, 1], [-2, 1], [3,1]])
print(matriz)
# Out:
# [[ 4  1]
#  [-2  1]
#  [ 3  1]]

# %%
matriz_pse = np.linalg.pinv(matriz)
print(matriz_pse)
# Out:
# [[ 0.11290323 -0.17741935  0.06451613]
#  [ 0.14516129  0.62903226  0.22580645]]

# %%
b = np.array([[3], [5], [1]])
print(b)
# Out:
# [[3]
#  [5]
#  [1]]

# %%
resultado = matriz_pse.dot(b)
print(resultado)
# Out:
# [[-0.48387097]
#  [ 3.80645161]]

# %%
x = np.linspace(-5, 5, 1000)

y_1 = -4*x + 3
y_2 = 2*x + 5
y_3 = -3*x + 1 

plt.plot(x, y_1)
plt.plot(x, y_2)
plt.plot(x, y_3)

plt.xlim(-2, 2.5)
plt.ylim(-6, 6)

#agregamos el punto encontrado
plt.scatter(resultado[0],  resultado[1])

plt.show()

# %% [markdown]
# Vemos que el punto no se encuentra en el centro del triangulo, esto lo podemos ententer por que las ecuaciones tienen distintos pesos, cada una esta tirando(jalando) el punto cerca de ella, como ejerciendo un centro de gravedad moviendolo. Siendo la ecuacion y_2 = 2*x + 5 la de mayor peso.

# %%
y_1 = -4*x + 3
y_2 = 2*x + 5
y_3 = -3*x + 1

# %%
matriz = np.array([[4, 1], [-2, 1], [3,1]])
print(matriz)

# %%
matriz_pse = np.linalg.pinv(matriz)
print(matriz_pse)

# %%
y_1 = 1*x + 4
y_2 = 2*x + 5
y_3 = -3*x + 6

# %%
matriz = np.array([[1, 2], [3, 4], [5,6]])
print(matriz)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
matriz_pse = np.linalg.pinv(matriz)
print(matriz_pse)
# Out:
# [[-1.33333333 -0.33333333  0.66666667]
#  [ 1.08333333  0.33333333 -0.41666667]]

# %%
b = np.array([[4], [5], [6]])
print(b)
# Out:
# [[4]
#  [5]
#  [6]]

# %%
resultado = matriz_pse.dot(b)
print(resultado)
# Out:
# [[0.28571429]
#  [5.        ]]

# %%
A = np.array([[3, 4],[3, 2]])

# %%
autovalores, autovectores = np.linalg.eig(A)

# %%
print(autovalores)
# Out:
# [ 6. -1.]

# %%
print(autovectores)
# Out:
# [[ 0.8        -0.70710678]
#  [ 0.6         0.70710678]]

# %%
autovectores.dot(np.diag(autovalores)).dot(autovectores.T)
# Out:
# array([[3.34, 3.38],
#        [3.38, 1.66]])

# %%
autovalores.dot(np.diag(autovectores))
# Out:
# 4.092893218813453

# %%
autovalores.dot(np.diag(autovectores))..dot(autovalores.T)
# Out:
#   File "<ipython-input-35-6e39aadc7b04>", line 1
#     autovalores.dot(np.diag(autovectores))..dot(autovalores.T)
#                                            ^
# SyntaxError: invalid syntax

# %%
autovectores.dot(np.diag(autovalores))
# Out:
# array([[ 4.8       ,  0.70710678],
#        [ 3.6       , -0.70710678]])
