# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.array([[-1,3], [2,-2]])
print(A)
# Out:
# [[-1  3]
#  [ 2 -2]]

# %%
vector = np.array([[2],[1]])
print(vector)
# Out:
# [[2]
#  [1]]

# %% [markdown]
# Importamos la funcion graficarVectores

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd 'drive/My Drive/Colab Notebooks/Curso algebra lineal aplicada a ML'/
# Out:
# /content/drive/My Drive/Colab Notebooks/Curso algebra lineal aplicada a ML

# %%
# %run "./funciones_auxiliares/graficarVectores.ipynb"

# %%
print(vector)
print(vector.flatten())
# flatten() nos devuelve el vector/matriz en formato horizontal
# Out:
# [[2]
#  [1]]
# [2 1]

# %%
print(A)
# Out:
# [[-1  3]
#  [ 2 -2]]

# %%
print(A.flatten())
# Out:
# [-1  3  2 -2]

# %%
graficarVectores([vector.flatten()], cols='blue')

plt.xlim(-0.5, 3)
plt.ylim(-0.5, 2)
# Out:
# (-0.5, 2.0)

# %% [markdown]
# Aplicando la transformacion al vector usando producto interno de la matriz A

# %%
vector_transformado = A.dot(vector)
print(vector_transformado)
# Out:
# [[1]
#  [2]]

# %%
graficarVectores([vector.flatten(), vector_transformado.flatten()],
                 cols=['blue', 'orange'])

plt.xlim(-0.5, 3)
plt.ylim(-0.5, 3)
# Out:
# (-0.5, 3.0)

# %%
print(np.linalg.det(A))
# Out:
# -4.0

# %% [markdown]
# Midiendo la distancia euclidiana de los vectores

# %%
print(np.linalg.norm(vector))
# Out:
# 2.23606797749979

# %%
print(np.linalg.norm(vector_transformado))
# Out:
# 2.23606797749979
